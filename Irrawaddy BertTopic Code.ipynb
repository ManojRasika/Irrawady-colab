# %%
# !pip install bertopic
from bertopic import BERTopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached bertopic-0.12.0-py2.py3-none-any.whl (90 kB)
# ...
#   Using cached PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# ...
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
# ...
#   Using cached umap-learn-0.5.3.tar.gz (88 kB)
# ...
#   Using cached hdbscan-0.8.29.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached transformers-4.24.0-py3-none-any.whl (5.5 MB)
# ...
#   Using cached sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# ...
#   Using cached huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
# ...
#   Using cached tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# ...
#   Using cached pynndescent-0.5.8.tar.gz (1.1 MB)
# ...

# %%
# !pip install --upgrade joblib==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 306 kB 8.9 MB/s
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# ...

# %%
from bertopic import BERTopic

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Up to the code line [27] I have used un cleaned data to feed into the BERTopic model.

# %%
df = pd.read_csv('/Article_text - Irrawaddy.csv')
df.head()
# Out:
#                                                 Page
# 0  c("\r\n                                       ...
# 1  There have been daily protests in front of the...
# 2  Responding to accusations that China is sendin...
# 3  Global Times said Western forces are making us...
# 4  In front of the Chinese Embassy, one placard h...

# %%
topic_model = BERTopic(language="english")
topics =topic_model.fit_transform(df.Page)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                  Name
# 0      -1    684                      -1_the_and_of_to
# 1       0    180             0_junta_myanmar_rn_topics
# 2       1    110                               1_rn___
# 3       2     81              2_chinese_meets_china_of
# 4       3     81              3_china_chinese_they_and
# 5       4     57              4_pdfs_resistance_the_of
# 6       5     53                     5_gas_oil_to_said
# 7       6     50             6_defectors_asylum_are_to
# 8       7     45      7_russia_russian_ukraine_myanmar
# 9       8     41                8_that_you_the_culture
# 10      9     40                 9_hun_asean_sen_visit
# 11     10     36             10_inya_residence_14_lake
# 12     11     35       11_topics_rn_national_democracy
# 13     12     34            12_karen_knla_knu_fighting
# 14     13     33           13_thai_thailand_border_and
# 15     14     33                14_his_min_hlaing_aung
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here [27] line onwards down below the BRETopic analysis was performed with the data that I cleaned from the R. Here I have created a corpus of words which are unrelated to  war.

# %%
df = pd.read_csv('/content/Article_text - Irrawaddy_cleaned.csv')
df.head()
# Out:
#                                                 Page
# 0                beijing mouthpiece global times ...
# 1            mao zedong established  peoples repu...
# 2             regime  seeking  adopt   cybersecur...
# 3     david scott mathieson      recent job posti...
# 4        september   seen  saddest daysâ€     fr...

# %%
topic_model = BERTopic(language="english")
topics =topic_model.fit_transform(df.Page)

# %%
#@title Default title text
topic_model.get_topic_info()
# Out:
#    Topic  Count                              Name
# 0     -1    122       -1_regime_people_aung_state
# 1      0     66        0_china_aung_regime_hlaing
# 2      1     17            1_aung_inya_hlaing_win
# 3      2     17         2_state_karen_regime_knla
# 4      3     14  3_children_regime_sagaing_people
# 5      4     12      4_india_state_indian_rakhine

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
! git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
! git commit -m "first commit"
# Out:
# On branch master
#
# Initial commit
#
# Untracked files:
# 	.config/
# 	sample_data/
#
# nothing added to commit but untracked files present

# %%
! git branch -M main
# Out:
# error: refname refs/heads/master not found
# fatal: Branch rename failed

# %%
! git config --global user.email "01manojrasika10@gmail.com"

# %%
# !git clone https://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@github.com/ManojRasika/Irrawady-colab.git
# Out:
# Cloning into 'Irrawady-colab'...
# ...
